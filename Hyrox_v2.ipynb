# %% [markdown]
# # Hyrox Scraping and Data Extraction
#
#
#
#
# This scraper is designed to systematically collect detailed information from the Hyrox race event website for a specified season. At a high level, the scraper operates through several key steps and components, tailored to efficiently navigate the structure of the Hyrox website and extract valuable data on race participants and their performances.
#
# Here's a summary of its core functionalities:
#
# `Dynamic URL Construction`: The scraper constructs URLs to access race event pages based on the specified season, incorporating necessary query parameters to filter events by various criteria such as gender and division. This dynamic approach allows for flexibility in targeting different seasons or specific event categories.
#
# `Page Navigation`: It includes logic to navigate through the pagination of event listings, ensuring that all available events within a season are accounted for. This is crucial for comprehensive data collection, given the website's structure of listing multiple events across several pages.
#
# `Data Extraction`: For each event URL visited, the scraper employs BeautifulSoup to parse the HTML content, extracting detailed participant data. This includes participant names, performance metrics, scoring details, and workout results, among other relevant information.
#
# `Data Structuring`: Extracted data is structured into a clean, organized format, making it suitable for analysis or storage. The scraper handles the flattening of nested data (like participant details and workout results) to ensure it can be efficiently stored in a CSV file or database.
#
# `Scalability and Adaptability`: The scraper is designed with modularity in mind, allowing for easy adjustments to target different seasons or accommodate changes in the website's structure. Parameters like the base URL, event codes, and query parameters can be updated to extend the scraper's utility across different seasons.
#
# `CSV Output`: Finally, the scraper compiles the collected data into a CSV file, providing a structured and accessible format for data analysis, reporting, or use in front-end applications. This includes adding new columns for gender and event ID, enhancing the data's usefulness for detailed performance analytics.

# %% [markdown]
# ##Beautiful Soup Approach
#
# BeautifulSoup implies a significant change in approach. Instead of interacting with the website through a browser (clicking buttons, waiting for JavaScript to render content, etc.), you'll need to make HTTP requests to the website URLs directly and parse the returned HTML content. This approach works well for static content but may not work if the content is loaded dynamically with JavaScript after the initial page load.

# %% [markdown]
# *   page=1: Specifies the page number.
# *   event=HPRO_JGDMS4JI6BA: Specifies the event ID.
# *   num_results=100: Sets the number of results per page to 100.
# *   pid=list: Indicates the type of content to retrieve.
# *   pidp=ranking_nav: A parameter likely related to the navigation or display of rankings.
# *   ranking=time_finish_netto: Specifies the ranking type.
# *   search[sex]=M: Filters results for male participants (assuming M stands for male).
# *   search[age_class]=%25: Appears to be a placeholder for age class filtering, %25 URL-decodes to %, which might be used here to mean "all" or "any".
# *  search[nation]=%25: Similar to age_class, this filters by nation, with %25 indicating no specific filte

# %%
import requests
from bs4 import BeautifulSoup

class HyroxEvent:
    def __init__(self, event_id, season):
        self.event_id = event_id
        self.season = season

# Complete list of events for half of season 5
events = [
    HyroxEvent(event_id="999999212F07B50000000079", season=1),
    HyroxEvent(event_id="999999212F07B50000000068", season=1),
    HyroxEvent(event_id="999999212F07B50000000066", season=1),
    HyroxEvent(event_id="999999212F07B50000000065", season=1),
    HyroxEvent(event_id="999999212F07B50000000052", season=1),
    HyroxEvent(event_id="999999212F07B50000000051", season=1),
    HyroxEvent(event_id="999999212F07B5000000003D", season=1),
    HyroxEvent(event_id="999999212F07B50000000029", season=1),
    HyroxEvent(event_id="999999212F07B50000000015", season=1),

]

divisions = {"open": "H", "pro": "HPRO", "elite": "HE"}
genders = ["M", "W"]

def get_page_urls(base_url, page_number, event, division_code, gender, season):
    full_event_code = f"{division_code}_{event.event_id}"  # Adjusted to use event object
    url = f"{base_url}/season-{season}/?page={page_number}&event={full_event_code}&lang=EN_CAP&num_results=100&pid=list&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D={gender}&search%5Bage_class%5D=%25&search%5Bnation%5D=%25"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    detail_urls = [a['href'] for a in soup.select("h4.list-field.type-fullname a")]
    return detail_urls, soup

def has_next_page(soup):
    next_page_button = soup.select_one("ul.pagination li.pages-nav-button a")
    return bool(next_page_button)

def main():
    base_url = "https://results.hyrox.com"
    all_detail_urls = []

    for event in events:  # Iterating over HyroxEvent objects
        for division_name, division_code in divisions.items():
            for gender in genders:
                page_number = 1
                while True:
                    urls, soup = get_page_urls(base_url, page_number, event, division_code, gender, event.season)  # Pass HyroxEvent object to get_page_urls
                    if not urls:
                        break
                    all_detail_urls.extend(urls)
                    print(f"Collected {len(urls)} URLs from event {event.event_id}, {division_name}, {gender}, page {page_number} in season {event.season}.")
                    if not has_next_page(soup):
                        break
                    page_number += 1

    print(f"Total collected URLs: {len(all_detail_urls)}")
    return all_detail_urls

# Execute the main function
collected_urls = main()
print(collected_urls)
# Out:
# Collected 100 URLs from event 999999212F07B50000000068, open, M, page 1 in season 1.
# Collected 45 URLs from event 999999212F07B50000000068, open, M, page 2 in season 1.
# Collected 77 URLs from event 999999212F07B50000000068, open, W, page 1 in season 1.
# Collected 41 URLs from event 999999212F07B50000000068, pro, M, page 1 in season 1.
# Collected 8 URLs from event 999999212F07B50000000068, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000066, open, M, page 1 in season 1.
# Collected 75 URLs from event 999999212F07B50000000066, open, M, page 2 in season 1.
# Collected 70 URLs from event 999999212F07B50000000066, open, W, page 1 in season 1.
# Collected 65 URLs from event 999999212F07B50000000066, pro, M, page 1 in season 1.
# Collected 20 URLs from event 999999212F07B50000000066, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, open, M, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, open, M, page 2 in season 1.
# Collected 62 URLs from event 999999212F07B50000000065, open, M, page 3 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, open, W, page 1 in season 1.
# Collected 8 URLs from event 999999212F07B50000000065, open, W, page 2 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, pro, M, page 1 in season 1.
# Collected 6 URLs from event 999999212F07B50000000065, pro, M, page 2 in season 1.
# Collected 31 URLs from event 999999212F07B50000000065, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000052, open, M, page 1 in season 1.
# Collected 80 URLs from event 999999212F07B50000000052, open, M, page 2 in season 1.
# Collected 83 URLs from event 999999212F07B50000000052, open, W, page 1 in season 1.
# Collected 61 URLs from event 999999212F07B50000000052, pro, M, page 1 in season 1.
# Collected 17 URLs from event 999999212F07B50000000052, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000051, open, M, page 1 in season 1.
# Collected 32 URLs from event 999999212F07B50000000051, open, M, page 2 in season 1.
# Collected 70 URLs from event 999999212F07B50000000051, open, W, page 1 in season 1.
# Collected 41 URLs from event 999999212F07B50000000051, pro, M, page 1 in season 1.
# Collected 12 URLs from event 999999212F07B50000000051, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B5000000003D, open, M, page 1 in season 1.
# Collected 52 URLs from event 999999212F07B5000000003D, open, M, page 2 in season 1.
# Collected 73 URLs from event 999999212F07B5000000003D, open, W, page 1 in season 1.
# Collected 39 URLs from event 999999212F07B5000000003D, pro, M, page 1 in season 1.
# Collected 10 URLs from event 999999212F07B5000000003D, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 2 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 3 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 4 in season 1.
# Collected 47 URLs from event 999999212F07B50000000029, open, M, page 5 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, W, page 2 in season 1.
# Collected 53 URLs from event 999999212F07B50000000029, open, W, page 3 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, pro, M, page 1 in season 1.
# Collected 56 URLs from event 999999212F07B50000000029, pro, M, page 2 in season 1.
# Collected 41 URLs from event 999999212F07B50000000029, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000015, open, M, page 1 in season 1.
# Collected 47 URLs from event 999999212F07B50000000015, open, M, page 2 in season 1.
# Collected 74 URLs from event 999999212F07B50000000015, open, W, page 1 in season 1.
# Collected 42 URLs from event 999999212F07B50000000015, pro, M, page 1 in season 1.
# Collected 5 URLs from event 999999212F07B50000000015, pro, W, page 1 in season 1.
# Total collected URLs: 3143
# ['?content=detail&fpid=list&pid=list&idp=999999212F07B50000009DBD&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000D28D&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000667F&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000B591&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B50000001F7D&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000D675&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B500000090ED&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000CA59&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000A7D4&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B50000008FEA&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000B66E&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B50000009192&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000D5EB&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000B43D&lang=EN_CAP&event=H_999999212F07B50000000068&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=H_999999212F07B50000000068', '?content=detail&fpid=list&pid=list&idp=999999212F07B5000000C06F&lang=EN_CAP&event=H_999999212F07B500000000 ...

# %% [markdown]
# This script uses **requests** and BeautifulSoup for web scraping, along with re for regular expression operations, to extract detailed information about participants from a specified URL. The get_participant_details function fetches the page, parses HTML content, and compiles participant details, scoring data, workout results, and overall time into a structured dictionary.
#
# Key steps include:
#
# Sending an HTTP request to the provided URL and parsing the HTML response.
# Using regular expressions to clean specific text fields, such as removing parentheses from names.
# Iterating through different sections of the HTML document to extract participant details, scoring, workout results, and overall times based on their respective HTML structures.
# Storing extracted information in a well-organized dictionary for easy access and readability.
# Finally, the script pretty prints the collected participant details for verification. This methodical approach enables detailed data extraction from complex web pages, suitable for applications requiring in-depth analysis of web content.
#
# Replace the url variable with the target page URL to apply this script to other web scraping tasks.

# %%
import requests
from bs4 import BeautifulSoup
import re
import csv
from urllib.parse import urlparse, parse_qs

def get_participant_details(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Parse the URL to extract query parameters
    parsed_url = urlparse(url)
    query_params = parse_qs(parsed_url.query)

    # Extract Gender and Event ID from query parameters
    gender = query_params['search[sex]'][0] if 'search[sex]' in query_params else 'Unknown'
    event_id = query_params['event'][0] if 'event' in query_params else 'Unknown'

    # Remove division code from event_id if present
    if '_' in event_id:
        event_id = event_id.split('_', 1)[1]

    details = {
        'Participant': {},
        'Scoring': {},
        'Workout Result': [],
        'Overall Time': {},
        'Gender': gender,
        'Event ID': event_id
    }

   # Define a regular expression pattern to find parentheses and their contents

    pattern = re.compile(r'\s*\([^)]*\)')

    # Extract Participant Details
    for participant_row in soup.select(".box-general table tr"):
        desc = participant_row.find("th", class_="desc").get_text(strip=True)
        # Check if the cell contains an image with an 'alt' attribute
        img = participant_row.find("td", class_="last").find("img")
        if img and img.has_attr('alt'):
            value = img['alt']
        else:
            value = participant_row.find("td", class_="last").get_text(strip=True)
        details['Participant'][desc] = value

        # Remove parentheses and their contents from the name
        if desc == 'Name':
            value = pattern.sub('', value).strip()
        details['Participant'][desc] = value

    # Extract Scoring Details
    for scoring_row in soup.select(".box-eventinfo table tr"):
        desc = scoring_row.find("th", class_="desc").get_text(strip=True)
        value = scoring_row.find("td", class_="last").get_text(strip=True)
        details['Scoring'][desc] = value

    # Extract Workout Results
    for workout_row in soup.select(".box-other table tr"):
    # Check if row is a header or has relevant data
      if workout_row.find("th", class_="desc"):
        columns = workout_row.find_all("td")
        workout = {
            'Split': workout_row.find("th", class_="desc").get_text(strip=True),
            'Time': columns[0].get_text(strip=True) if len(columns) > 0 else None,
            'Place': columns[1].get_text(strip=True) if len(columns) > 1 else None
        }
        details['Workout Result'].append(workout)

    # Extract Overall Time
    for overall_row in soup.select(".box-totals table tr"):
        desc = overall_row.find("th", class_="desc").get_text(strip=True)
        value = overall_row.find("td", class_="last").get_text(strip=True)
        details['Overall Time'][desc] = value

    return details

# URL for testing, replace with your actual list of URLs
url = 'https://hyrox.r.mikatiming.de/season-6/?content=detail&fpid=list&pid=list&idp=JGDMS4JI9C378&lang=EN_CAP&event=HPRO_JGDMS4JI6BA&num_results=100&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25&search_event=HPRO_JGDMS4JI6BA'
participant_details = get_participant_details(url)




# Pretty printing the results
from pprint import pprint
pprint(participant_details)
# Out:
# {'Event ID': 'JGDMS4JI6BA',
#  'Gender': 'M',
#  'Overall Time': {'Overall Time': '01:00:33',
#                   'Rank (AG)': '2',
#                   'Rank (M/W)': '2'},
#  'Participant': {'Age Group': '25-29',
#                  'Name': 'Williamson, Jake',
#                  'Nat': 'GBR',
#                  'Number': '200004'},
#  'Scoring': {'Division': 'HYROX PRO', 'Race': '2024 Manchester'},
#  'Workout Result': [{'Place': '–', 'Split': 'Running 1', 'Time': '00:03:14'},
#                     {'Place': '10',
#                      'Split': '1000m SkiErg',
#                      'Time': '00:03:44'},
#                     {'Place': '–', 'Split': 'Running 2', 'Time': '00:03:33'},
#                     {'Place': '21',
#                      'Split': '50m Sled Push',
#                      'Time': '00:02:57'},
#                     {'Place': '–', 'Split': 'Running 3', 'Time': '00:03:47'},
#                     {'Place': '16',
#                      'Split': '50m Sled Pull',
#                      'Time': '00:04:04'},
#                     {'Place': '–', 'Split': 'Running 4', 'Time': '00:03:52'},
#                     {'Place': '5',
#                      'Split': '80m Burpee Broad Jump',
#                      'Time': '00:02:40'},
#                     {'Place': '–', 'Split': 'Running 5', 'Time': '00:03:47'},
#                     {'Place': '3', 'Split': '1000m Row', 'Time': '00:03:56'},
#                     {'Place': '–', 'Split': 'Running 6', 'Time': '00:03:50'},
#                     {'Place': '20',
#                      'Split': '200m Farmers Carry',
#                      'Time': '00:01:37'},
#                     {'Place': '–', 'Split': 'Running 7', 'Time': '00:03:55'},
#                     {'Place': '21',
#                      'Split': '100m Sandbag Lunges',
#                      'Time': '00:03:53'},
#                     {'Place': '–', 'Split': 'Running 8', 'Time': '00:04:11'},
#                     {'Place': '5', 'Split': 'Wall Balls', 'Time': '00:04:04'},
#                     {'Place': '8', 'Split': 'Roxzone Time', 'Time': '00:03:36'},
#                     {'Place': '9', 'Split': 'Run Total', 'Time': '00:30:05'},
#                     {'Place': '7',
#                      'Split': 'Best Run Lap',
#                      'Time': '00:03:14'}]}

# %%
import time

def scrape_all_participants(base_url):
    collected_urls = main()  # Retrieve the list of URLs to scrape
    all_participant_details = []  # Initialize a list to store details of all participants

    total_urls = len(collected_urls)  # Total number of URLs to scrape
    start_time = time.time()  # Record the start time of the scraping process

    for index, url in enumerate(collected_urls, start=1):
        full_url = base_url + url
        participant_details = get_participant_details(full_url)  # Scrape participant details
        all_participant_details.append(participant_details)

        # Print scraped participant's name for progress tracking
        print(f"Scraped details for {participant_details['Participant'].get('Name', 'Unknown')}")

        # Time estimation logic
        current_time = time.time()
        elapsed_time = current_time - start_time
        avg_time_per_url = elapsed_time / index
        estimated_total_time = avg_time_per_url * total_urls
        estimated_remaining_time = estimated_total_time - elapsed_time

        # Print time estimation every 100 URLs or at certain intervals
        if index % 100 == 0:
            print(f"Completed {index} of {total_urls} URLs.")
            print(f"Estimated remaining time: {estimated_remaining_time/60:.2f} minutes.")

    return all_participant_details

if __name__ == "__main__":
    base_url = "https://hyrox.r.mikatiming.de/season-1/"  # Adjust if necessary
    all_details = scrape_all_participants(base_url)
    print(f"Scraping completed. Total profiles scraped: {len(all_details)}")
# Out:
# Collected 100 URLs from event 999999212F07B50000000068, open, M, page 1 in season 1.
# Collected 45 URLs from event 999999212F07B50000000068, open, M, page 2 in season 1.
# Collected 77 URLs from event 999999212F07B50000000068, open, W, page 1 in season 1.
# Collected 41 URLs from event 999999212F07B50000000068, pro, M, page 1 in season 1.
# Collected 8 URLs from event 999999212F07B50000000068, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000066, open, M, page 1 in season 1.
# Collected 75 URLs from event 999999212F07B50000000066, open, M, page 2 in season 1.
# Collected 70 URLs from event 999999212F07B50000000066, open, W, page 1 in season 1.
# Collected 65 URLs from event 999999212F07B50000000066, pro, M, page 1 in season 1.
# Collected 20 URLs from event 999999212F07B50000000066, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, open, M, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, open, M, page 2 in season 1.
# Collected 62 URLs from event 999999212F07B50000000065, open, M, page 3 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, open, W, page 1 in season 1.
# Collected 8 URLs from event 999999212F07B50000000065, open, W, page 2 in season 1.
# Collected 100 URLs from event 999999212F07B50000000065, pro, M, page 1 in season 1.
# Collected 6 URLs from event 999999212F07B50000000065, pro, M, page 2 in season 1.
# Collected 31 URLs from event 999999212F07B50000000065, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000052, open, M, page 1 in season 1.
# Collected 80 URLs from event 999999212F07B50000000052, open, M, page 2 in season 1.
# Collected 83 URLs from event 999999212F07B50000000052, open, W, page 1 in season 1.
# Collected 61 URLs from event 999999212F07B50000000052, pro, M, page 1 in season 1.
# Collected 17 URLs from event 999999212F07B50000000052, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000051, open, M, page 1 in season 1.
# Collected 32 URLs from event 999999212F07B50000000051, open, M, page 2 in season 1.
# Collected 70 URLs from event 999999212F07B50000000051, open, W, page 1 in season 1.
# Collected 41 URLs from event 999999212F07B50000000051, pro, M, page 1 in season 1.
# Collected 12 URLs from event 999999212F07B50000000051, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B5000000003D, open, M, page 1 in season 1.
# Collected 52 URLs from event 999999212F07B5000000003D, open, M, page 2 in season 1.
# Collected 73 URLs from event 999999212F07B5000000003D, open, W, page 1 in season 1.
# Collected 39 URLs from event 999999212F07B5000000003D, pro, M, page 1 in season 1.
# Collected 10 URLs from event 999999212F07B5000000003D, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 2 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 3 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, M, page 4 in season 1.
# Collected 47 URLs from event 999999212F07B50000000029, open, M, page 5 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, open, W, page 2 in season 1.
# Collected 53 URLs from event 999999212F07B50000000029, open, W, page 3 in season 1.
# Collected 100 URLs from event 999999212F07B50000000029, pro, M, page 1 in season 1.
# Collected 56 URLs from event 999999212F07B50000000029, pro, M, page 2 in season 1.
# Collected 41 URLs from event 999999212F07B50000000029, pro, W, page 1 in season 1.
# Collected 100 URLs from event 999999212F07B50000000015, open, M, page 1 in season 1.
# Collected 47 URLs from event 999999212F07B50000000015, open, M, page 2 in season 1.
# Collected 74 URLs from event 999999212F07B50000000015, open, W, page 1 in season 1.
# Collected 42 URLs from event 999999212F07B50000000015, pro, M, page 1 in season 1.
# Collected 5 URLs from event 999999212F07B50000000015, pro, W, page 1 in season 1.
# Total collected URLs: 3143
# Scraped details for Künsler, Stefan
# Scraped details for Reineke, Fabian
# Scraped details for Blöbaum, Ole
# Scraped details for Schunack, Martin
# Scraped details for Schmitz, Andreas
# Scraped details for Jeffery, Kai
# Scraped details for Abromeit, Tim
# Scraped details for Westerhaus, Michael
# Scraped details for Fox, Lucas
# Scraped details for Stalph, Joachim
# Scraped details for Dr. Freistedt, Daniel
# Scraped details for Schick, Carsten
# Scraped details for Holz, Dustin
# Scraped details for Röwekamp, Lennard
# Scraped details for Lichtenberger, Kai
# Scraped details for Dahlkamp, Michael
# Scraped details for Wiacek, Adam
# Scraped details for Pach, Alexander
# Scraped details for Kösters, Sven
# Scraped details for Wundersee, Philipp
# Scraped details for Marbach, Jan
# Scraped details for Sadikov, Artem
# Scraped details for Zilligers, Markus
# Scraped details for Dr. Romanowski, Jacek
# Scraped details for Schürmann, Philipp
# Scraped details for Schröder, Michael
# Scraped details for Schüßler, Benjamin
# Scraped details for Mehdi, Mohamad
# Scraped details for Majenka, Robert
# Scraped details for Schumacher, Thilo
# Scraped details for Dykhuis, Florian
# Scraped details for Weiler, Florian
# Scraped details for Nägler, Guido
# Scraped details for Schött, Dominik
# Scraped details for Morano, Johnny
# Scraped details for Schopa, Patrick
# Scraped details for Baum, Jonas
# Scraped details for Schmieszek, Oliver
# Scraped details for Schrödter, Tim-Arvid
# Scraped details for Bennedsen, Frank
# Scraped details for Raschke, Fabian
# Scraped details for Dohmen, Oliver
# Scraped details for Hottmann, Artur
# Scraped details for Adler, Andre
# Scraped details for Gerstner, Rene
# Scraped details for Pikkemaat, Patrick
# Scraped details for August, Elias
# Scraped details for Choudeloudis, Christos
# Scraped details for Wawer, Lennard
# Scraped details for Höltgen, Carlo
# Scraped details for Lehrmann, Julian
# Scraped details for Popp, Gregor
# Scraped details for Thul, Lars
# Scraped details for Splettstößer, Daniel
# Scraped details for Lange, Andreas
# Scraped details for Barkholz, Sascha
# Scraped details for Hamer, Mirko
# Scraped details for Hemmling, Nils
# Scraped details for Heinzle, Tim
# Scraped details for Lödden, Christian
# Scraped details for Oremek, Sebastian
# Scraped details for Griesbach, Tobias
# Scraped details for Ehlers, Oliver
# Scraped details for Mudra, Heiko
# Scraped details for Strobl, Stefan
# Scraped details for Boßlet, Philipp
# Scraped details for Limke, Sebastian
# Scraped details for Zyla, Robert
# Scraped details for Wilcisk, Jörg
# Scraped details for Hagemeier, Micha
# Scraped details for Mußbach, Marvin
# Scraped details for Hüge, Martin
# Scraped details for Hausdorf, Mike
# Scraped details for Enger, Andre
# Scraped details for Baur, Moritz
# Scraped details for Wittek, Kai
# Scraped details for Burckardt, Frank
# Scraped details for Schirrmacher, Sascha
# Scraped details for Prof. Mantilla, Frederik
# Scraped details for Morsche, Julian
# Scraped details for Schier, Dennis
# Scraped details for Leppin, Uwe
# Scraped details for Hanenberg, Stefan
# Scraped details for Linke, Sascha
# Scraped details for Mersch, Thierry
# Scraped details for Boll, Frederic
# Scraped details for Kolditz, Heiko
# Scraped details for Paulat, Dirk
# Scraped details for Kreuzberger, Johannes
# Scraped details for Jakubiak, Lukas
# Scraped details for Barbaro, Vincenzo
# Scraped details for Manojlovic, Igor
# Scraped details for Kara, Dogan
# Scraped details for Schork, David
# Scraped details for Breznikar, Lars
# Scraped details for Becker, Stefan
# Scraped details for Jochems, Maurice
# Scraped details for Dr. Mayer, Christian
# Scraped details for Flak, Thomas
# Scraped details for Meise, Benjamin
# Completed 100 of 3143 URLs.
# Estimated remaining time: 39.50 minutes.
# Scraped details for Jonczyk, Sebastian
# Scraped details for Seiler, Karl
# Scraped details for Graef, Henry
# Scraped details for Ebus, Frank
# Scraped details for Henkel, Marcel
# Scraped details for Gstettenbauer, Lars
# Scraped details for Treptow, Maik
# Scraped details for Lessing, Thorsten
# Scraped details for Thomschke, Andreas
# Scraped details for Bau, Andreas
# Scraped details for Kunze, Mike
# Scraped details for Pham, Thao
# Scraped details for Theil, Michael
# Scraped details for Schubert, Philipp
# Scraped details for Schwind, Armin
# Scraped details for Krauss, Kevin
# Scraped details for Konatschnig, Günther
# Scraped details for Kube, Marco
# Scraped details for Heidt, Bastian
# Scraped details for Dr. Busch, Alexander
# Scraped details for Butscher, Stefan
# Scraped details for Schneiderath, Brian
# Scraped details for Hey, Mathias
# Scraped details for Krainz, Johannes
# Scraped details for Schürmann, Peter
# Scraped details for Kaller, Michael
# Scraped details for Natzke, Dirk
# Scraped details for Meichsner, Florian
# Scraped details for Sinzig, Eike
# Scraped details for Franke, Patrick
# Scraped details for Andersen, Sören
# Scraped details for Traub, Oliver
# Scraped details for Leuker, Christoph
# Scraped details for Fabry, Hans
# Scraped details for Zeitz, Björn
# Scraped details for Sivanayagam, Ajeeth
# Scraped details for Mehdi, Yasar
# Scraped details for Daemen, Uwe
# Scraped details for Wickert, Ralf
# Scraped details for Kolde, Thomas
# Scraped details for Clasen, Sebastian
# Scraped details for Dehler, Vincent
# Scraped details for Eickfeld, Michael
# Scraped details for Ochs, Andreas
# Scraped details for Schünemann, David
# Scraped details for Winterfeldt, Barbara
# Scraped details for Henkel, Petra
# Scraped details for Regenkiewicz, Anita
# Scraped details for Monin, Jana
# Scraped details for Leckes-Debre, Daniela
# Scraped details for Stilling, Anne
# Scraped details for Hutzler, Beate
# Scraped details for Mesech, Trixi
# Scraped details for Michaelis, Stephanie
# Scraped details for Sand, Julia
# Scraped details for Kaiser, Sonja
# Scraped details for Moores, Stefanie
# Scraped details for Bolesta, Maiken
# Scraped details for Meierkord, Britta
# Scraped details for Kübler, Claudia
# Scraped details for Altemeier, Christina
# Scraped details for Hey, Patricia
# Scraped details for Küppers, Andrea
# Scraped details for Hansen, Charlotte
# Scraped details for Hülsmann, Silke
# Scraped details for Schroven, Jane
# Scraped details for Wenning, Marina
# Scraped details for Torregrossa, Nicole
# Scraped details for Butzek, Nina
# Scraped details for Schneider, Jasmin
# Scraped details for Dr. Nissen, Annik
# Scraped details for Zwartscholten, Gesa
# Scraped details for Dieguez Alonso, Maribel
# Scraped details for Woitzik, Victoria
# Scraped details for Zander, Marina
# Scraped details for Schütze, Katharina
# Scraped details for Kaspschak, Anja
# Scraped details for Preuss, Jacqueline
# Scraped details for Wolff, Charlyn
# Scraped details for Rocker, Anna Lena
# Scraped details for Semple, Sarah
# Scraped details for Huhtamella, Sirpa
# Scraped details for Giering, Bianca
# Scraped details for Busmann, Laura
# Scraped details for Schmidt, Sandra
# Scraped details for Tillmann, Melanie
# Scraped details for Wrobel, Martha
# Scraped details for Stock, Victoria
# Scraped details for Wakup, Anja
# Scraped details for Schönfeld, Susanne
# Scraped details for Gosselk, Anke
# Scraped details for Leuker, Melina
# Scraped details for Hensel, Karina
# Scraped details for Hajok, Eva
# Scraped details for Linse, Stefanie
# Scraped details for Jahnke, Stefanie
# Scraped details for Marx, Ulla
# Scraped details for Heise, Sandra
# Scraped details for Reißenweber, Alexandra
# Scraped details for Schneider, Anke
# Completed 200 of 3143 URLs.
# Estimated remaining time: 38.19 minutes.
# Scraped details for Hartmann, Marina
# Scraped details for E Markowski, Caroline
# Scraped details for Hemme, Samira
# Scraped details for Soemansah, Estrella
# Scraped details for Ampferer, Anita
# Scraped details for Breining, Michelle
# Scraped details for Lewandowski, Nicole
# Scraped details for Kube, Katharina
# Scraped details for Karsten, Marlen
# Scraped details for Schmitz, Simone
# Scraped details for Horsmans, Kelly
# Scraped details for Dubberke, Svenja
# Scraped details for Esch, Eva
# Scraped details for Meinel, Jana
# Scraped details for Heinen, Julia
# Scraped details for Sausen, Jennifer
# Scraped details for Schumacher, Svenja
# Scraped details for Backes, Alexandra
# Scraped details for Althaus, Rebecca
# Scraped details for Fausten, Jane
# Scraped details for Pohlmann, Stefanie
# Scraped details for Wölting, Bianca
# Scraped details for Schwarzkopf, Dieter
# Scraped details for Manthey, Björn
# Scraped details for Lütters, Frank
# Scraped details for Eibl, Christoph
# Scraped details for Afarwuah, Kofi
# Scraped details for Lüke, Dennis
# Scraped details for Prof. Dr. Jess, Benedikt
# Scraped details for Baginski, Tobias
# Scraped details for Meinking, Matthias
# Scraped details for Quack, Benjamin
# Scraped details for Wagner, Willi
# Scraped details for De Vries, Tilko
# Scraped details for Kowalczyk, Florian
# Scraped details for Jüng, Sebastian
# Scraped details for Jansen, Tobias
# Scraped details for Propp, Dmitrij
# Scraped details for Frisch, Oliver
# Scraped details for Feuerschütz, Simon
# Scraped details for Sörös, Manfred
# Scraped details for Seidnitzer, Jan
# Scraped details for Redekop, Andre
# Scraped details for Heins, Sebastian
# Scraped details for Kannenberg, Jesko David
# Scraped details for Köster, Marvin
# Scraped details for Wollicki, Kevin
# Scraped details for Hartmann, Danny
# Scraped details for Janning, Lars
# Scraped details for Vogt, Stephan
# Scraped details for Brée, Dominique
# Scraped details for Güther, Thomas
# Scraped details for Pachula, David
# Scraped details for Matthiesen, Lars
# Scraped details for Langenohl, Rene
# Scraped details for Klotz, Bojan
# Scraped details for Bergemann, Benedikt
# Scraped details for Vlad, Gabriel
# Scraped details for Hütten, Christian
# Scraped details for Schroer, Klaus
# Scraped details for Mai, Andreas
# Scraped details for Schlagintweit, Thomas
# Scraped details for Jacobsen, Tim
# Scraped details for Wielens, Jessica
# Scraped details for Bickel, Lina
# Scraped details for Eckhardt, Melanie
# Scraped details for Dumke, Louisa
# Scraped details for Bender, Bianca
# Scraped details for Thyssen-Schneider, Carmen
# Scraped details for Helberg, Julia
# Scraped details for Formelke, Roxy
# Scraped details for Nestvogel, Benjamin
# Scraped details for Gamp, Ludwig
# Scraped details for Reinhard, Frank
# Scraped details for Schwab, Sebastian
# Scraped details for Fischer, Florian
# Scraped details for Barsties, Philipp
# Scraped details for Schmidtfall, Paul
# Scraped details for D‘Antino, Dominic
# Scraped details for Schuhmann, Marius
# Scraped details for Majewski, Adrian
# Scraped details for Music, Joschka
# Scraped details for Heim, Benedikt
# Scraped details for Sticker, Sebastian
# Scraped details for Brändel, Maik
# Scraped details for Mulzer, Michael
# Scraped details for May, Markus
# Scraped details for Krause, Meiko
# Scraped details for Holz, Dustin
# Scraped details for Wentorf, Mathias
# Scraped details for Bader, Nicolas
# Scraped details for Hermle, Marc-Anthony
# Scraped details for Fried, Steffen
# Scraped details for Ghazi, Ali
# Scraped details for Lukas, Frank
# Scraped details for Seitz, Rüdiger
# Scraped details for Mayr, Ed
# Scraped details for Seewald, Christopher
# Scraped details for Schübel, Michael
# Scraped details for Krell, Michael
# Completed 300 of 3143 URLs.
# Estimated remaining time: 36.96 minutes.
# Scraped details for Kirsten, Ingo
# Scraped details for Hodolitsch, Georg
# Scraped details for Hofer, Jürgen
# Scraped details for Daumann, Ole
# Scraped details for Böhm, Martin
# Scraped details for Fuchs, Sebastian
# Scraped details for Dold, Christoph
# Scraped details for Rabenstein, Axel
# Scraped details for Röderer, Johannes
# Scraped details for Welsch, Fabian
# Scraped details for Hanke, Daniel
# Scraped details for Wos, Lucas
# Scraped details for Müller, Martin
# Scraped details for Stücken, Philipp
# Scraped details for Man, Wai-Yip
# Scraped details for Ravaglioli, Samuel
# Scraped details for Schröder, Michael
# Scraped details for Gehring, Simon
# Scraped details for Tritschler, Benjamin
# Scraped details for Kirchdörfer, Frank
# Scraped details for Scheit, Marvin
# Scraped details for Rottstädt, Max
# Scraped details for Poncette, Marc
# Scraped details for Bönigk, Julian
# Scraped details for Esskandari, Manzur
# Scraped details for Raschke, Fabian
# Scraped details for Helmer, Florian
# Scraped details for Nordmeier, Jens
# Scraped details for Oks, Chris
# Scraped details for Treml, Felix
# Scraped details for Bannenberg, Steffen
# Scraped details for Motteler, Marcel
# Scraped details for Grebe, Michael
# Scraped details for Terentiv, Leon
# Scraped details for Herzog, Markus
# Scraped details for Dr. Sahanoglu, Fatih
# Scraped details for Kinsky, Simon
# Scraped details for Thome, Christoph
# Scraped details for E Sperling, Fabian
# Scraped details for Nuss, Harald Tom
# Scraped details for Muggli, Stephan
# Scraped details for Tetiwa, Jan
# Scraped details for Fiedler, Stefan
# Scraped details for Knab, Yannik
# Scraped details for Schneider, Rick
# Scraped details for Schelte, Lorenz
# Scraped details for Gebhardt, Michael
# Scraped details for Jager, Sven
# Scraped details for Meckel, Marco
# Scraped details for Perzl, Andre
# Scraped details for Funk, Michael
# Scraped details for Matzer-Kernich, Maximilian
# Scraped details for Kammerer, Tim
# Scraped details for Keupp, Jürgen
# Scraped details for Nguyen, David
# Scraped details for Martynow, Wladimir
# Scraped details for Titze, Tobias
# Scraped details for Schmeisser, Dominik
# Scraped details for Eggert, Moritz
# Scraped details for Ritter, Frank
# Scraped details for Shahhosini, Nima
# Scraped details for Dr. Nagel, Julius
# Scraped details for Kindermann, Stefan
# Scraped details for Heuberger, Sebastian
# Scraped details for Gering, Stefan
# Scraped details for Schupp, Timo
# Scraped details for Steinbrecher, Mario
# Scraped details for Vogel, Dominik
# Scraped details for Schött, Dominik
# Scraped details for Kunze, Sebastian
# Scraped details for Stemmer, Christoph
# Scraped details for Ferstl, Markus
# Scraped details for Albayrak, Mikdat
# Scraped details for Bielchen, Christian
# Scraped details for Thomas, Michael
# Scraped details for Pell, Pierre
# Scraped details for Neumann, Dieter
# Scraped details for Köppl, Ulrich
# Scraped details for Schiegg, Florian
# Scraped details for Müller, Christian
# Scraped details for Hofmann, Christian
# Scraped details for Prof. Dr. Ohr, Jürgen
# Scraped details for Prützel, Jürgen
# Scraped details for Fritsch, Johannes
# Scraped details for Gerstner, Rene
# Scraped details for Olvera Gutierrez, Oscar
# Scraped details for Mirschberger, Giovanni
# Scraped details for Grönert, Andreas
# Scraped details for Tihme, Alexander
# Scraped details for Heim, Simon
# Scraped details for Behl, Roland
# Scraped details for Zawrel, Benjamin
# Scraped details for Lau, Thomas
# Scraped details for Rohrbach, Marco
# Scraped details for Allmeritter, Stefan
# Scraped details for Gogesch, Johann
# Scraped details for Behnke, Dirk
# Scraped details for Koch, Johannes
# Scraped details for Schuberth, Jakob
# Scraped details for Reiter, Thomas
# Completed 400 of 3143 URLs.
# Estimated remaining time: 35.67 minutes.
# Scraped details for Benassi, Alessandro
# Scraped details for Baumüller, Konstantin
# Scraped details for Beckers, Victor
# Scraped details for Kolitsch, Andy
# Scraped details for Kondratenko, Denys
# Scraped details for Schaller, Andreas
# Scraped details for Reißenweber, Jonas
# Scraped details for Kolberg, Matthias
# Scraped details for Jablonski, Andre
# Scraped details for Sontopski, Marc
# Scraped details for Hummel, Dominik
# Scraped details for Hartung, Thomas
# Scraped details for Schubert, Alexander
# Scraped details for Gerlach, Alexander
# Scraped details for Grad, Cyrill
# Scraped details for Winter, Thorsten
# Scraped details for Fischer, Frank
# Scraped details for Ziegenthaler, Uli
# Scraped details for Diebolder, Joey
# Scraped details for Man, Wai-Hung
# Scraped details for Portisch, Johannes
# Scraped details for Pastow, Moritz
# Scraped details for Riedesel, Tobias
# Scraped details for Ehgartner, André
# Scraped details for Dr. Braeske, Knud
# Scraped details for Stiefenhofer, Philipp
# Scraped details for Pauli, Thomas
# Scraped details for Foerster, Ole
# Scraped details for Schleweck, Marc
# Scraped details for Saßmannshausen, Marius
# Scraped details for Sageder, Sebastian
# Scraped details for Ullmann, Harald
# Scraped details for Schreiber, Arnold
# Scraped details for Thieme, Jürgen
# Scraped details for Sargin, Anatol
# Scraped details for Lehmann, Alexander
# Scraped details for Mesec, Franc
# Scraped details for Köhler, Ramon
# Scraped details for Baier, Florian
# Scraped details for Obendorf, Marc
# Scraped details for Massar, Philipp
# Scraped details for Lechner, Florian
# Scraped details for Györy, Kalman
# Scraped details for Gröbner, Rene
# Scraped details for Akanyildiz, Berkay
# Scraped details for Drieß, Thorsten
# Scraped details for Sheehy, Angela
# Scraped details for Jaud, Christina
# Scraped details for Taubert, Victoria
# Scraped details for Eberle, Fleurine
# Scraped details for Barkawitz, Susann
# Scraped details for Miller, Nicole
# Scraped details for Engert, Raphaela
# Scraped details for Sontopski, Silke
# Scraped details for Stutzmann, Mona
# Scraped details for Lutz, Annina
# Scraped details for Nicklas, Katja
# Scraped details for Röhm, Stefanie
# Scraped details for Borchert, Clarissa
# Scraped details for Sand, Julia
# Scraped details for Münzenmayer, Rebekka
# Scraped details for Voigt, Charlotte
# Scraped details for Gericke, Lisa
# Scraped details for Rogalsky, Katja
# Scraped details for Von Der Weth, Nicole
# Scraped details for Grimm, Sophia
# Scraped details for Nees, Kim-Selina
# Scraped details for Hummel, Kristin
# Scraped details for Kübler, Claudia
# Scraped details for Preuß, Tamina
# Scraped details for Kleinlein, Theresa
# Scraped details for Majewski, Lina
# Scraped details for Bayer, Julia
# Scraped details for Brauer, Eva Katharina
# Scraped details for Schmidt, Benedikta
# Scraped details for Grimm, Kathrin
# Scraped details for Burghardt, Sonja
# Scraped details for Heimisch, Daniela
# Scraped details for Schui, Susanne-Frederike
# Scraped details for Philip, Ira
# Scraped details for Köhler, Juliane
# Scraped details for Torregrossa, Nicole
# Scraped details for Förch, Andrea
# Scraped details for Fischer, Sandra
# Scraped details for Moeckel, Tanja
# Scraped details for Schmidt, Silke
# Scraped details for Šimunjak, Nadine
# Scraped details for Salzgeber, Michaela
# Scraped details for Hippenstiel, Kim Jasmin
# Scraped details for Sauer, Dewa
# Scraped details for Reiher, Nicole
# Scraped details for Spitz, Sinah
# Scraped details for Newman, Natalja
# Scraped details for Halle, Olga
# Scraped details for Axer, Stephanie
# Scraped details for Ullmann, Claudia
# Scraped details for Schwerdtner, Simone
# Scraped details for Ritter, Veronika Marion
# Scraped details for Harr, Jasmin
# Scraped details for Groh, Tina
# Completed 500 of 3143 URLs.
# Estimated remaining time: 34.36 minutes.
# Scraped details for Höning, Emily
# Scraped details for Jung, Susanne
# Scraped details for Helmer, Viola
# Scraped details for Heim, Katharina
# Scraped details for Krawczyk, Michelle
# Scraped details for Schuster, Nicole
# Scraped details for Unterweger, Sandra
# Scraped details for Fischer, Kristin
# Scraped details for Stefan, Andrea
# Scraped details for Hübner, Liliana
# Scraped details for Beier, Jacqueline
# Scraped details for Riedl, Monika
# Scraped details for Cistakova, Jessica
# Scraped details for Althaus, Rebecca
# Scraped details for Werner, Kathrin Tanja
# Scraped details for Werner, Kathrin Tanja
# Scraped details for Storath, Lukas
# Scraped details for Wamser, Philipp
# Scraped details for Jasny, Manuel
# Scraped details for Flade, Max
# Scraped details for Gast, Florian
# Scraped details for Fuchs, Peter
# Scraped details for Rattenberger, Manuel
# Scraped details for Weig, Simon
# Scraped details for Schaubert, Benedikt
# Scraped details for Schröder, Tim
# Scraped details for Michelius, Martin
# Scraped details for Tanz, Tobias
# Scraped details for Baiker, Felix
# Scraped details for Grohmann, Tim
# Scraped details for Flade, Markus
# Scraped details for Pranjic, Ivan
# Scraped details for Kemmer, Thomas
# Scraped details for Reusch, Florian
# Scraped details for Mühle, Eric
# Scraped details for Effenberger, Tim
# Scraped details for Haupt, Benjamin
# Scraped details for Rosenfeld, Marco
# Scraped details for Zaoui, Djamal
# Scraped details for Fuchs, Markus
# Scraped details for Sandreuther, Daniel
# Scraped details for Schiller, Chris
# Scraped details for Träxler, Martin
# Scraped details for Bohlmann, Magnus
# Scraped details for Rochler, Louis
# Scraped details for Marsching, René
# Scraped details for Fuchs, Andreas
# Scraped details for Minnert, Kevin
# Scraped details for Kügler, Janis
# Scraped details for Neubauer, Felix
# Scraped details for Godulla, Frank
# Scraped details for Preißler, Sven
# Scraped details for Eberhardt, Hannes
# Scraped details for Schäfer, Moritz
# Scraped details for Kramer, Dennis
# Scraped details for Fröhlich, Thomas
# Scraped details for Rößner, Benjamin
# Scraped details for Freitag, Florian
# Scraped details for Pachernig, Markus
# Scraped details for Hörold, Jonas
# Scraped details for Mayr, Franz
# Scraped details for Heib, Tobias
# Scraped details for Wittmayr, Manuel
# Scraped details for Csulits, Markus
# Scraped details for Holweg, David
# Scraped details for Fischer, Manuel
# Scraped details for Krumpel, Hans-Peter Uwe
# Scraped details for Geitner, Stefan
# Scraped details for Speer, Daniel
# Scraped details for Henninger, Philipp
# Scraped details for Qudsi, Abdul
# Scraped details for Heine, Julian
# Scraped details for Martach, Detlef
# Scraped details for Simon, Marc
# Scraped details for Weber, Stefano
# Scraped details for Schmidt, Marco
# Scraped details for Forisch, Roland
# Scraped details for Baranowski, Sebastian
# Scraped details for Giegerich, Felix
# Scraped details for Schöbel, Nils
# Scraped details for Kiki, Aziz
# Scraped details for Steffen, Laura
# Scraped details for Blank, Katharina
# Scraped details for Schubert, Magdalena
# Scraped details for Jefimova, Viktorija
# Scraped details for Bungard, Carina
# Scraped details for Gleich, Melanie
# Scraped details for Ellenrieder, Antonia
# Scraped details for Skolik, Olivia
# Scraped details for Schnell, Andrea
# Scraped details for Faatz, Susan
# Scraped details for Thussbas, Sophia
# Scraped details for Klose, Linda
# Scraped details for Wolff, Nadine
# Scraped details for Özdemir, Özlem
# Scraped details for Zemmin, Nadine
# Scraped details for Rekersbrink, Alix
# Scraped details for Lipsky, Stefanie
# Scraped details for Castillo Reyes, Maisofy
# Scraped details for Ramuschkat, Lisa
# Completed 600 of 3143 URLs.
# Estimated remaining time: 33.06 minutes.
# Scraped details for Kügle, Julia Johanna
# Scraped details for Diemann, Johann-Sebastian
# Scraped details for Dr. Schnetger, Patrick
# Scraped details for Witte, Jonas
# Scraped details for Bube, Max
# Scraped details for Müller, Philipp
# Scraped details for Eilers, Daniel
# Scraped details for Nestvogel, Benjamin
# Scraped details for Goltermann, Arne
# Scraped details for Hartung, Jan
# Scraped details for Gomeringer, Michael
# Scraped details for D‘Antino, Dominic
# Scraped details for Schneider, Christian
# Scraped details for Kaller, Pierre
# Scraped details for Schwerin, Adrian
# Scraped details for Thiem, Sebastian
# Scraped details for Sauthoff, Dean
# Scraped details for Ritter, Alexander
# Scraped details for Schwarze, Matthias
# Scraped details for Fugmann, Björn
# Scraped details for Hennig, Frank
# Scraped details for Rohmann, Nic
# Scraped details for Belov, Jan
# Scraped details for Tesfazghi, Awet
# Scraped details for Huwer, Eric
# Scraped details for Rolfes, Lars
# Scraped details for Scheibe, Tim
# Scraped details for Witt, Alexander
# Scraped details for Kaller, Dennis
# Scraped details for Wilmar, Torben
# Scraped details for Judt, Alexander
# Scraped details for Kohl, Michael
# Scraped details for Jeffery, Kai
# Scraped details for Reinelt, Tobias
# Scraped details for Bruns, Andreas
# Scraped details for Fiebig, Christian
# Scraped details for Schnabel, Peter
# Scraped details for Stankiewicz, Marcin
# Scraped details for Mörth, Sascha
# Scraped details for Bremer, Daniel
# Scraped details for Prof. Dr. Vetter, Stanislaus
# Scraped details for Hamann, Kim
# Scraped details for Bachmann, Lev
# Scraped details for Schlütemann, Kai
# Scraped details for Deßmann, Denis
# Scraped details for Ehle, Maximilian
# Scraped details for Froböse, Thilo
# Scraped details for Oehlerking, Jonas
# Scraped details for Raab, Kenny
# Scraped details for Molkenthin, Klaus
# Scraped details for Brandt, Silvan
# Scraped details for Wildgrube, Marcel
# Scraped details for Wagner, Willi
# Scraped details for Vettermann, Leon
# Scraped details for Esskandari, Manzur
# Scraped details for Kästner, Martin
# Scraped details for Kohnert, Malte
# Scraped details for Holz, Dustin
# Scraped details for Scheerle, Benjamin
# Scraped details for Holzäpfel, Tim
# Scraped details for Rendchen, Manuel
# Scraped details for Gold, Marom
# Scraped details for Vinogradovs, Aleksejs
# Scraped details for Meloni, Maurizio
# Scraped details for Nägler, Guido
# Scraped details for Kossack, Torben
# Scraped details for Haase, Andre
# Scraped details for Gerke, Falk
# Scraped details for Schoof, Lars
# Scraped details for Fried, Steffen
# Scraped details for Particke, Phil
# Scraped details for Gruendel, Oliver
# Scraped details for Janßen, Andreas
# Scraped details for Böttcher, Dirk
# Scraped details for Schult, Guido
# Scraped details for Schunack, Martin
# Scraped details for Kel, Egidijus
# Scraped details for Behnsen, Henning
# Scraped details for Rohmann, Vince
# Scraped details for Haase, Sven
# Scraped details for Horsthemke, Alexander
# Scraped details for Feuerschütz, Simon
# Scraped details for Hagen, Robert
# Scraped details for Shirokov, Aleksandr
# Scraped details for Welzel, Knut
# Scraped details for Laabs, Jan
# Scraped details for Wos, Lucas
# Scraped details for Tehsmann, Dirk
# Scraped details for Ligeti, Norman
# Scraped details for Mehl, Alexander
# Scraped details for Pöhl, Patrick
# Scraped details for Genath, Rene
# Scraped details for Sonder, Marco
# Scraped details for Knappmeier, Marco
# Scraped details for Winter, Stephan
# Scraped details for Riede, Nicolas
# Scraped details for Humbert, André
# Scraped details for Schirmer, Thorsten
# Scraped details for Gärtner, Joachim
# Scraped details for Döhn, André
# Completed 700 of 3143 URLs.
# Estimated remaining time: 31.76 minutes.
# Scraped details for Barke, Johannes
# Scraped details for Liebing, Marko
# Scraped details for Meier, Christoph
# Scraped details for Schlichenmaier, Tom
# Scraped details for Granzow, Rick
# Scraped details for Couzinet, Marlon
# Scraped details for Göllner, Hauke
# Scraped details for Breuer, Moritz
# Scraped details for Rottstädt, Max
# Scraped details for Wolf, Peter
# Scraped details for Jasniak, Thimo
# Scraped details for Awiszus, Martin
# Scraped details for Wündsch, Lukas
# Scraped details for Cordes, Paul
# Scraped details for Alex, Michael
# Scraped details for Arkenberg, Marcel
# Scraped details for Cardinier, Pascal
# Scraped details for Schött, Dominik
# Scraped details for Grabowski, Tim
# Scraped details for Dohmen, Oliver
# Scraped details for Lewandowski, André
# Scraped details for Griener, Christopher
# Scraped details for Fredrich, Jörn
# Scraped details for Blechinger, Jan
# Scraped details for Fläschner, Alexander
# Scraped details for Tondera, Daniel
# Scraped details for Kwiatkowski, David
# Scraped details for Justa, Christian
# Scraped details for Theil, Kilian
# Scraped details for Vettin, Christian
# Scraped details for Oremek, Sebastian
# Scraped details for Enger, Andre
# Scraped details for Schmidt, Lars
# Scraped details for Schiffer, Karl-Heinz
# Scraped details for Kroos, Michael
# Scraped details for Matthies, Felix
# Scraped details for Sandelmann, Lars
# Scraped details for Papadoudis, Chrisovalantis
# Scraped details for Böhme, David
# Scraped details for Schnur, Christian
# Scraped details for Schnur, Christian
# Scraped details for Segebarth, Heiko
# Scraped details for Kröger, Mathis
# Scraped details for Weyers, Valentin
# Scraped details for Gaul, Stephan
# Scraped details for Huesmann, Alexander
# Scraped details for Schäfer, Marc
# Scraped details for Schliep, Jörn
# Scraped details for Piechotta, Christian
# Scraped details for Schwippel, Janik
# Scraped details for Bettels, Alexander
# Scraped details for Unterhuber, Lennart
# Scraped details for Tietz, Christian
# Scraped details for Westermann, Martin
# Scraped details for Brauer, Sebastian
# Scraped details for Weise, Kai
# Scraped details for Bähre, Boris
# Scraped details for Hürten, Felix
# Scraped details for Walter, Jürgen
# Scraped details for Kellermeier, Christoph
# Scraped details for Jung, Oliver
# Scraped details for Mach, Reik
# Scraped details for Hüge, Martin
# Scraped details for Barkholz, Sascha
# Scraped details for Leukert, Philipp
# Scraped details for Flessel, Rainer
# Scraped details for Dörks, Ben
# Scraped details for Mevert, Heiko
# Scraped details for Ragab, Ahmed
# Scraped details for Leuschel, Marvin
# Scraped details for Mudra, Heiko
# Scraped details for Roschen, Sven
# Scraped details for Wölfle, Justus
# Scraped details for Kühnlenz, Tom
# Scraped details for Wawer, Lennard
# Scraped details for Rohrmoser, Jens-Uwe
# Scraped details for Neumann, Dustin
# Scraped details for Kayser, Jonas
# Scraped details for Spengel, Gunnar
# Scraped details for Knirsch, Calvin
# Scraped details for Thies, Franz
# Scraped details for Renzler, Marcus
# Scraped details for Müller, Nico
# Scraped details for Schwarze, Kevin
# Scraped details for d Enrich, Bruno
# Scraped details for Würdemann, Tim
# Scraped details for Heipke, Dennis
# Scraped details for Sohn, Michael
# Scraped details for Kruse, Andy
# Scraped details for Dienelt, Timo
# Scraped details for Winter, Thomas
# Scraped details for Raasch, Christian
# Scraped details for Sarnecki, Lukas
# Scraped details for Bloch, Erik
# Scraped details for Starke, Andreas
# Scraped details for Pflugradt, Luca
# Scraped details for Rothe, Raphael
# Scraped details for Stackmann, Jens Michael
# Scraped details for Hoffmann, Christian
# Scraped details for Sauerwald, Dirk
# Completed 800 of 3143 URLs.
# Estimated remaining time: 30.43 minutes.
# Scraped details for Motz, Oliver
# Scraped details for Schmidt, Thorsten
# Scraped details for Jeske, Philipp
# Scraped details for Kühling, Joshua
# Scraped details for Spitzenberg, Leon
# Scraped details for Niemann, Markus
# Scraped details for Fromm, Steven
# Scraped details for Matz, Martin
# Scraped details for Friedrich, Tim
# Scraped details for Trampler, Götz
# Scraped details for Stephan, Robert
# Scraped details for Scholz-Winkelmann, Nico
# Scraped details for Behrens, Matt
# Scraped details for Kurz, Ruben
# Scraped details for Hübner, Tom
# Scraped details for Zörkendörfer, Martin
# Scraped details for Benner, Martin
# Scraped details for Ulrich, Timo
# Scraped details for Stojanoski, Darijan
# Scraped details for Bischoff, Jan
# Scraped details for Haase, Frank
# Scraped details for Jahnke, Volker
# Scraped details for Fricke, Rayk
# Scraped details for Schmitt, Torben
# Scraped details for Vennemann, Torben
# Scraped details for Möller, Dirk
# Scraped details for Gaca, Michael
# Scraped details for Pflugradt, Marco
# Scraped details for Esskandari, Timur
# Scraped details for Sosa Breyer, Javier
# Scraped details for Lill, Thomas
# Scraped details for Popov, Akim
# Scraped details for Krieger, Lars
# Scraped details for Sehn, Vasco
# Scraped details for Blohm, Daniel
# Scraped details for Vroom, Lennard
# Scraped details for Thiemann, Torsten
# Scraped details for Schmudig, Kai
# Scraped details for Graffius, Marcus
# Scraped details for Schuch, Bernd
# Scraped details for Richter, Leif
# Scraped details for Jeiteles, Philip
# Scraped details for Oswald, Sebastian
# Scraped details for Beitat, Benjamin
# Scraped details for Schmuck, Christian
# Scraped details for Schmuck, Christian
# Scraped details for Grimmler, Michael
# Scraped details for Schneider, Andreas
# Scraped details for Hopp, Christian
# Scraped details for Pöhler, Volker
# Scraped details for Teske, Jan
# Scraped details for Gröffel, Henning
# Scraped details for Göring, Martin
# Scraped details for Göbel, Dennis
# Scraped details for Grieben, Björn
# Scraped details for Kellen, Sebastian
# Scraped details for Schacht, Thomas
# Scraped details for Günzroth, Rene
# Scraped details for Schwerdtfeger, Robert
# Scraped details for Siegl, Stefan
# Scraped details for Nikolic, Bojan
# Scraped details for Rudolph, Björn
# Scraped details for Rudolph, Chris
# Scraped details for Nüser, Katharina
# Scraped details for Konrad, Juliane
# Scraped details for Laue, Annika
# Scraped details for Rolfs, Ida
# Scraped details for Segger, Maylin
# Scraped details for Hoffmann, Louisa
# Scraped details for Brüning, Sophie
# Scraped details for Schöber, Sonja
# Scraped details for Bobie, Angelika
# Scraped details for Leineweber, Kerstin
# Scraped details for Röthig, Sabrina
# Scraped details for Klemm, Marina
# Scraped details for Jungmann, Carolin
# Scraped details for Mbamba, Mariam
# Scraped details for Stichweh, Alina
# Scraped details for Humbert, Corinna
# Scraped details for Ruhnau, Caroline
# Scraped details for Monin, Jana
# Scraped details for Zeitschel, Laura
# Scraped details for Keckeis, Stefanie
# Scraped details for Wartenberg, Patricia
# Scraped details for Letford, Nicole
# Scraped details for Thiel, Silke
# Scraped details for Lange, Franziska
# Scraped details for Merten, Isabell-Lisanne
# Scraped details for Starke, Jennifer
# Scraped details for Bohlen, Alicia
# Scraped details for Kunze, Kathrin
# Scraped details for Eichhorn, Monica
# Scraped details for Diekmann, Kimberly
# Scraped details for Uhlisch, Bianca
# Scraped details for Müller, Maike
# Scraped details for Kittelmann, Clara
# Scraped details for Spaude, Janina
# Scraped details for Mau, Melissa
# Scraped details for Fauske, Clarissa
# Scraped details for Janßen, Svenja
# Completed 900 of 3143 URLs.
# Estimated remaining time: 29.14 minutes.
# Scraped details for Beckmann, Fenja
# Scraped details for Westerhorstmann, Theresa
# Scraped details for Tehsmann, Madeleine
# Scraped details for Kaiser, Sonja
# Scraped details for Rutkowski, Sonja
# Scraped details for Remmers, Annemarie
# Scraped details for Herzberg, Louisa
# Scraped details for Lohmann, Sophie
# Scraped details for Müller, Jennifer
# Scraped details for Deutschmann, Ina
# Scraped details for Jahn, Lisa
# Scraped details for Klaas, Lea
# Scraped details for Haase, Jana
# Scraped details for Tekin, Meltem
# Scraped details for Klawitter, Julia
# Scraped details for Behnsen, Saskia
# Scraped details for Kaspschak, Anja
# Scraped details for Iversen, Frida
# Scraped details for Sliwiok, Jessica
# Scraped details for Dyballa, Dorothee
# Scraped details for Schmidt, Jacqueline
# Scraped details for Hardt, Yonna
# Scraped details for Block, Freda
# Scraped details for Pflugradt, Jana
# Scraped details for Mauer, Silja
# Scraped details for Kähler, Lisa
# Scraped details for Conradt, Carolin
# Scraped details for Jürss, Carlotta
# Scraped details for Tian, Yuhan
# Scraped details for Ribel, Sofie
# Scraped details for Weiss, Caty
# Scraped details for Ralph, Monique
# Scraped details for Bruns, Katja
# Scraped details for Gentile, Susanne
# Scraped details for Giering, Bianca
# Scraped details for Weißhaar, Katharina
# Scraped details for Stock, Victoria
# Scraped details for Rohde, Margaret
# Scraped details for Jessen, Anita
# Scraped details for Menzel, Grit
# Scraped details for Ahrendt, Sophie
# Scraped details for Langensiepen, Ines
# Scraped details for Schirmer, Sandra
# Scraped details for Formelke, Roxana
# Scraped details for Dr. Nessler, Jasmin
# Scraped details for Brüggeboes, Mandy
# Scraped details for Tokarski, Sabrina
# Scraped details for Pfersich, Julia
# Scraped details for Lenschow, Alice
# Scraped details for Neidhardt, Theresa
# Scraped details for Fredebohm, Sabrina
# Scraped details for Storch, Lea
# Scraped details for Ulrich, Saskia
# Scraped details for Ramberg, Lini
# Scraped details for Esch, Eva
# Scraped details for Baczynski, Madeleine
# Scraped details for Kutsenko, Nadezhda
# Scraped details for Röpke, Christina
# Scraped details for Eichner, Andrea
# Scraped details for Gerwoll, Marie
# Scraped details for Spieckermann, Lesly
# Scraped details for Oberg-Baehre, Martina
# Scraped details for Lukas, Jannike
# Scraped details for Kaiser, Bettina
# Scraped details for Besser, Laura
# Scraped details for Gluth, Laura
# Scraped details for Borijcuk, Ksenia
# Scraped details for Tolkemitt, Jessica
# Scraped details for Keil, Jacqueline
# Scraped details for Wölting, Bianca
# Scraped details for Langen, Julia
# Scraped details for Jasny, Manuel
# Scraped details for Werner, Franz
# Scraped details for Walter, Tobias M.
# Scraped details for Bannasch, Jan
# Scraped details for Lüdeke, Jens
# Scraped details for Groetzsch, Pascal
# Scraped details for Grohmann, Tim
# Scraped details for Pape, Stephan
# Scraped details for Schwarzkopf, Dieter
# Scraped details for Prilop, Jens
# Scraped details for Kaiser, Lars
# Scraped details for Ellmers, Fabian
# Scraped details for Begehr, Fabian
# Scraped details for Loßin, Lars
# Scraped details for Preuß, Gunnar
# Scraped details for Birk, Steven
# Scraped details for Berresheim, Dirk Dorian
# Scraped details for Wolf, Benjamin
# Scraped details for Obenauer, Yannick
# Scraped details for Egelkraut, Marco
# Scraped details for Prange, Daniel
# Scraped details for Schulz-Meinen, Samir
# Scraped details for Von Der Assen, Ralf
# Scraped details for Schiller, Chris
# Scraped details for Vogt, Julian
# Scraped details for Kühn, Tobias
# Scraped details for Konrad-Werner, Dennis
# Scraped details for Seese, Torsten
# Scraped details for Ot, Patrick
# Completed 1000 of 3143 URLs.
# Estimated remaining time: 27.84 minutes.
# Scraped details for Stryga, Marvin
# Scraped details for Kleemann, Markus
# Scraped details for Imiela, Christoph
# Scraped details for Rehfeld, Pierre
# Scraped details for Schröder, Tim
# Scraped details for Afarwuah, Kofi
# Scraped details for Gerlich, Timo
# Scraped details for Reuter, André
# Scraped details for Rogge, Sven
# Scraped details for Bröcker, Marco
# Scraped details for Milde, Max
# Scraped details for Tanz, Tobias
# Scraped details for Lietfien, Holger
# Scraped details for Schmidt, Jannik
# Scraped details for Willhaus, Dirk
# Scraped details for Löper, Jörg
# Scraped details for Özdemir, Harun
# Scraped details for Schöneboom, Helge
# Scraped details for Sarpal, Ishwar
# Scraped details for Dierks, Sebastian
# Scraped details for Fremgens, Sebastian
# Scraped details for Dr. Matheis, Philipp
# Scraped details for Porath, Thorsten
# Scraped details for Wesemann, André
# Scraped details for Gerloff, Thorsten
# Scraped details for Sörös, Manfred
# Scraped details for Wichmann, Timo
# Scraped details for OERTEL, MAX
# Scraped details for Hillebrandt, Benjamin
# Scraped details for Meyer, Aike
# Scraped details for Lange, Patrick
# Scraped details for Radeck, Tobias
# Scraped details for Brand, Ove
# Scraped details for Huckfeldt, Jörg
# Scraped details for Kube, Dennis
# Scraped details for Struhs, Kenneth
# Scraped details for Redekop, Andre
# Scraped details for Geburek, Nicolai
# Scraped details for Richter, Fabian
# Scraped details for Abel, Ansgar
# Scraped details for Paasch, Sebastian
# Scraped details for De Vries, Tilko
# Scraped details for Witzel, Tobias
# Scraped details for Schellhammer, Lorenz
# Scraped details for Rother, Thomas
# Scraped details for Zandt, Paul
# Scraped details for Aalto, Esa-Matti
# Scraped details for Knorr, Thomas
# Scraped details for Tajik, Ramin
# Scraped details for Hartmann, Dominic
# Scraped details for Heins, Sebastian
# Scraped details for Thies, Björn
# Scraped details for Paulitz, Torsten
# Scraped details for Gaede, Stefan
# Scraped details for Mai, Xuan Tan
# Scraped details for Kuckuck, Jan
# Scraped details for Prudlik, Holger
# Scraped details for Gentzcke, Jan
# Scraped details for Pauleit, Florian
# Scraped details for Peter, Christopher
# Scraped details for Hein, Alexej
# Scraped details for Sharpe, Patrick
# Scraped details for Vorkapic, Miroslav
# Scraped details for Matthiesen, Lars
# Scraped details for Langenohl, René
# Scraped details for Pohl, Jannik
# Scraped details for Range, Markus
# Scraped details for Gerhold, Kevin
# Scraped details for Harlaß, Steffen
# Scraped details for Lang, Matthias
# Scraped details for Wilharm, Jasper
# Scraped details for Wendland, René
# Scraped details for Röhner, Max
# Scraped details for Sauer, Tom
# Scraped details for Peter, Sebastian
# Scraped details for Naumann, Bengt
# Scraped details for Rösener, Klaus-Dieter
# Scraped details for Naether, Rebecca
# Scraped details for Düngfelder, Lisa
# Scraped details for Schubert, Magdalena
# Scraped details for Landré, Nicole
# Scraped details for Dörks, Linda
# Scraped details for Knorr, Susanna
# Scraped details for Jefimova, Viktorija
# Scraped details for Vietmeier, Nadine
# Scraped details for Frankenau, Elisa
# Scraped details for Lechner, Franziska
# Scraped details for Schmidt, Anna-Lena
# Scraped details for Bajtl, Sonja
# Scraped details for Olivares Lagos, Estefania
# Scraped details for Kurz, Katharina
# Scraped details for Buchwald, Ina
# Scraped details for Schüller, Sabrina
# Scraped details for Bauer, Marina
# Scraped details for Breuer, Lea
# Scraped details for Fuhrmann, Katja
# Scraped details for Wittig, Franziska
# Scraped details for Freiwald, Grit
# Scraped details for Hahn, Isabella
# Scraped details for Schmitt, Karina
# Completed 1100 of 3143 URLs.
# Estimated remaining time: 26.54 minutes.
# Scraped details for Jahnke, Carmen
# Scraped details for Waszak, Katharina
# Scraped details for Weiß, Manuela
# Scraped details for Fuchs, Lina
# Scraped details for Letmathe, Katrin
# Scraped details for Wedemeyer, Nicole
# Scraped details for Brust, Theresa
# Scraped details for Kamradt, Sabrina
# Scraped details for Bengtsson, Carl
# Scraped details for Hoffmann, Robin
# Scraped details for Michel, Alban
# Scraped details for Alcantara, Jaime
# Scraped details for Grobmeier, Daniel
# Scraped details for Majewski, Adrian
# Scraped details for Teatiu, Florian
# Scraped details for Mauri, Daniele
# Scraped details for Huttelmaier, Jörg
# Scraped details for Müller, Andreas
# Scraped details for Lang, Peter
# Scraped details for Plessing, Jörg
# Scraped details for Emmert, Daniel
# Scraped details for Hermle, Marc-Anthony
# Scraped details for Unger, Daniel
# Scraped details for Schüll, Manuel
# Scraped details for Binzenhöfer, Julius
# Scraped details for Kleis, Thomas
# Scraped details for Godulla, Frank
# Scraped details for Stuible, Tim
# Scraped details for Brugger, Michael
# Scraped details for Kurz, Oliver
# Scraped details for Damke, Nils
# Scraped details for Ebel, Yann
# Scraped details for Schmidt, Birger
# Scraped details for Seck, Adrian
# Scraped details for Rühle, Tim
# Scraped details for Schille, Steffen
# Scraped details for Scheihing, Frank
# Scraped details for Rörich, Jürgen
# Scraped details for Grausam, Marco
# Scraped details for Man, Wai-Yip
# Scraped details for Mattes, Daniel
# Scraped details for Pfau, Karsten
# Scraped details for Lehnert, Frédéric
# Scraped details for Riedel, Frieder
# Scraped details for Kleinknecht, Florian
# Scraped details for Lindt, Marco
# Scraped details for Prigione, Paolo
# Scraped details for Renner, Simon
# Scraped details for Fromm, Viktor
# Scraped details for Gruber, Tim
# Scraped details for Backes, Stefan
# Scraped details for Djember, Nik
# Scraped details for Wieczorek, Kilian
# Scraped details for Duygun, Sahin
# Scraped details for Wenz, Florian
# Scraped details for Schuster, Daniel
# Scraped details for Stieber, Manuel
# Scraped details for Reuter, Christian
# Scraped details for Frey, Alexander
# Scraped details for Cvetko, Benjamin
# Scraped details for Slotty, Benjamin
# Scraped details for Jakob, Lange
# Scraped details for Raschke, Fabian
# Scraped details for Krieger, Martin
# Scraped details for Oberländer, Johannes
# Scraped details for Fefler, Eduard
# Scraped details for Lenz, Ronny
# Scraped details for Angehrn, Oliver
# Scraped details for Weis, Bernd
# Scraped details for Allgöwer, Robin
# Scraped details for Donner, Heinrich
# Scraped details for Fehrle, Kai
# Scraped details for Diedrich, Dominik
# Scraped details for Dr. Dobberkau, Nico
# Scraped details for Terrazzino-Ordonez, Brian
# Scraped details for Beckler, Julian
# Scraped details for Bollinger, Robert
# Scraped details for Hörold, Jonas
# Scraped details for Schumacher, Thilo
# Scraped details for Essler, Michael
# Scraped details for Helmer, Florian
# Scraped details for Klug, Malte
# Scraped details for Reckel, Jonas
# Scraped details for Schuster, Michael
# Scraped details for Weidemann, Sebastian
# Scraped details for Petersen, Sönke
# Scraped details for Kern, Andreas
# Scraped details for Müller, Martin
# Scraped details for Azargoon, Mohamad
# Scraped details for Grimm, Thomas
# Scraped details for Yanze Mbiaffeu, Steve Brice
# Scraped details for Utz, Vladimir
# Scraped details for Bormann, Philipp
# Scraped details for Köppl, Ulrich
# Scraped details for Kühner, Michael
# Scraped details for Markus, Dieter
# ...
# Scraped details for Schepers, Malte
# Scraped details for Stock, Raik
# Scraped details for Motz, Oliver
# Scraped details for Toetzke, Falko
# Scraped details for Mahn, Stefan
# Scraped details for Rothe, Raphael
# Scraped details for Henkel, Sven
# Scraped details for Lohse, Nico
# Scraped details for Esskandari, Timur
# Scraped details for Koopmann, Gunnar
# Scraped details for Rademacker, Tim
# Scraped details for Höhn, Andreas
# Scraped details for Nätebusch, Sebastian
# Scraped details for Just, Oliver
# Scraped details for Bloch, Erik
# Scraped details for Puls, Pascal
# Scraped details for Keßler, Jonas
# Scraped details for Peuckert, Markus
# Scraped details for Ede, Aykan
# Scraped details for Pentz, Niclaas Martin
# Scraped details for Castro, Christian
# Scraped details for Starck, Daniel
# Scraped details for Marquardsen, Marcel
# Scraped details for Saningong, Dr. Akuma
# Scraped details for Salehi, Nasser
# Scraped details for Schönlau, Nico
# Scraped details for Rothgänger- Capps, Roland
# Scraped details for Franke, Kai
# Scraped details for Giesau, Stephan
# Scraped details for Hoppe, Patrick
# Scraped details for Braun, David
# Scraped details for Tatides, Spiridon
# Scraped details for Schmuck, Christian
# Scraped details for Schmuck, Christian
# Scraped details for Buse, Michael
# Scraped details for Will, Thomas
# Scraped details for Hilgendorf, Odiri
# Scraped details for Kolberg, Marlon
# Scraped details for Hack, Sebastian
# Scraped details for Pape, Felix
# Scraped details for Al-Samir, Kais
# Scraped details for Voekt, Carlos
# Scraped details for Krogmann, Kevin
# Scraped details for Krupka, Philipp
# Scraped details for Raasch, Christian
# Scraped details for Piechotta, Christian
# Scraped details for Müller, Markus
# Scraped details for Peters, Christian
# Scraped details for Diesterbeck, Richard
# Scraped details for Hochbaum, Fabian
# Scraped details for Pflugradt, Marco
# Scraped details for Schmitt, Torben
# Scraped details for Meincke, André
# Scraped details for Sarnecki, Lukas
# Scraped details for Lam, Thai
# Scraped details for Ristok, Alexander
# Scraped details for Lumma, Maik
# Scraped details for Cetin, Israfil
# Scraped details for Kamann-Lewis, Simon
# Scraped details for Tonner, Johann
# Scraped details for Völker, Thomas
# Completed 2400 of 3143 URLs.
# Estimated remaining time: 9.66 minutes.
# Scraped details for Langner, Henry
# Scraped details for Langner, Johannes
# Scraped details for Rösener, Klaus-Dieter
# Scraped details for Krusenbaum, Kim
# Scraped details for Schimank, Kay
# Scraped details for Dr. Diekmann, Christian
# Scraped details for Pape, Noah
# Scraped details for Javidi, Ehsan
# Scraped details for Juhl, Nils
# Scraped details for Lohse, Markus
# Scraped details for Crawford, Eric
# Scraped details for Schoch, Jan
# Scraped details for Siekaup, Malte
# Scraped details for Cazimi, Jeton
# Scraped details for Cazimi, Jeton
# Scraped details for Frenkel, Max Thorkil
# Scraped details for Leonhardt, Lars
# Scraped details for Schur, Carsten
# Scraped details for Beyer, Marc-André
# Scraped details for Tomke, Stefan
# Scraped details for Leonhardt, Malte
# Scraped details for Joseph, Sebastian
# Scraped details for Stahl, Sebastian
# Scraped details for Manthey, Calvin
# Scraped details for Ballach, Andreas
# Scraped details for Wiesner, Sarah
# Scraped details for Nieschlag, Helke
# Scraped details for Krupp, Carolin
# Scraped details for Frähmcke, Nathalie Andrea
# Scraped details for Franke, Katharina
# Scraped details for Knorr, Susanna
# Scraped details for Ritter, Nicole
# Scraped details for Nüser, Katharina
# Scraped details for Konrad, Juliane
# Scraped details for Gerdey, Wiebke
# Scraped details for Schmidt, Katharina
# Scraped details for Günther, Sina
# Scraped details for D Schmitt, Karina
# Scraped details for Steingröver, Johanna
# Scraped details for Pasdzior, Beate
# Scraped details for Schöffzeck, Stephanie
# Scraped details for Jegminat, Vera Sophie
# Scraped details for Keckeis, Stefanie
# Scraped details for Kolb, Christine
# Scraped details for Petersdotter, Linn
# Scraped details for Grote, Jessica
# Scraped details for Sprenger, Christin
# Scraped details for Kopplin, Lydia
# Scraped details for Kummer, Dorothee
# Scraped details for Reichert, Käthe
# Scraped details for Nicolaisen, Svea
# Scraped details for Borucinska, Alicja
# Scraped details for Malik, Kristin
# Scraped details for Bank, Andrea
# Scraped details for Mertzokat, Katharina
# Scraped details for Huber, Andrea
# Scraped details for Mühlbeyer, Johanna
# Scraped details for Humbert, Corinna
# Scraped details for Cremer, Melanie
# Scraped details for Shmakova, Olga
# Scraped details for Bodendiek, Katy
# Scraped details for Meyer, Christina
# Scraped details for Schleiff, Lea
# Scraped details for Otto, Nadine
# Scraped details for Janssen, Sabrina
# Scraped details for Achenbach, Dania
# Scraped details for Scharfschwerdt, Petra
# Scraped details for Jacobsen, Christin
# Scraped details for Andresen, Jennifer
# Scraped details for Cardone, Anna-Rita
# Scraped details for Hardt, Yonna
# Scraped details for Burmeister, Naike
# Scraped details for Menke, Alice
# Scraped details for Röper, Jessica
# Scraped details for Colo, Viviana
# Scraped details for Klarmann, Anja
# Scraped details for Braun, JO
# Scraped details for Block, Jennifer
# Scraped details for Kovar, Katja
# Scraped details for König, Kaja
# Scraped details for Schwertz, Anna
# Scraped details for Kalbitz, Anne
# Scraped details for Wendel, Jackie
# Scraped details for Monin, Jana
# Scraped details for Jörn, Corinna
# Scraped details for Jaensch, Sophia
# Scraped details for Hommes, Katrin
# Scraped details for Rösler, Clara
# Scraped details for Zuber, Jennifer
# Scraped details for Hansen, Julia
# Scraped details for Käther, Nadja
# Scraped details for Castillo Tristán, Dinorah-Cecilia
# Scraped details for Kabisch, Silja-Mareen
# Scraped details for Baseda, Wiebke
# Scraped details for Schmeißer, Marie
# Scraped details for Lorenz, Andrea
# Scraped details for Lüdemann, Julia
# Scraped details for Rutkowski, Sonja
# Scraped details for Karttunen, Elli
# Scraped details for Gerull, Hanna
# Completed 2500 of 3143 URLs.
# Estimated remaining time: 8.36 minutes.
# Scraped details for Von Criegern, Dorothea
# Scraped details for Eichhorn, Monica
# Scraped details for Lüddeke, Frederike
# Scraped details for Luxenhofer, Lara Anita
# Scraped details for Wilhelms, Doreen
# Scraped details for Rutsch, Sarah
# Scraped details for Schulz, Laura
# Scraped details for Bobie, Angelika
# Scraped details for Tehsmann, Madeleine
# Scraped details for Bidermane, Ieva
# Scraped details for Pikal, Christine
# Scraped details for Gutbrodt, Simone
# Scraped details for Tophoven, Katharina
# Scraped details for Modrow, Anja
# Scraped details for Riemann, Milena
# Scraped details for Hilgendorf, Carmen
# Scraped details for Kyvalova, Zuzana
# Scraped details for Joas, Sarah
# Scraped details for Ehlert, Anna-Lena
# Scraped details for Löhden, Jana
# Scraped details for Ahrendt, Sophie
# Scraped details for Teller, Julia
# Scraped details for Fabisch, Leonie
# Scraped details for Lanig, Katharina
# Scraped details for Kruppa, Agnes
# Scraped details for Ramuschkat, Lisa
# Scraped details for Mollenhauer, Linnea
# Scraped details for Sorega-Unberath, Karina
# Scraped details for Oswald, Carolin
# Scraped details for Sallam, Scherin
# Scraped details for Funk, Nicola
# Scraped details for Steinert, Eva
# Scraped details for Kalbitz, Mareike
# Scraped details for Metzendorff, Nina
# Scraped details for Partes, Yvonne
# Scraped details for Schlange, Elke
# Scraped details for Ziebell, Anna
# Scraped details for Wedenin, Valeria
# Scraped details for Schmidt, Anna
# Scraped details for Lange, Sonja
# Scraped details for Krüger, Christin
# Scraped details for Köppe, Yvonne
# Scraped details for Jürss, Carlotta
# Scraped details for Dr. Orthmann, Anja
# Scraped details for Deutschmann, Ina
# Scraped details for Helgetveit, Ines
# Scraped details for Sticher, Claudia
# Scraped details for Wassill, Linda Gry
# Scraped details for Niemann, Victoria
# Scraped details for Leifels, Gabi
# Scraped details for Jessen, Anita
# Scraped details for Thies, Maren
# Scraped details for Lubach, Jana
# Scraped details for Pflugradt, Jana
# Scraped details for Dr. Rosenkranz, Sina
# Scraped details for Lichte, Nadja
# Scraped details for Barkmann, Hannah
# Scraped details for Dahncke, Stefanie
# Scraped details for Nyhuis, Karin
# Scraped details for Montag, Christine
# Scraped details for Brauer, Jeanette
# Scraped details for Schöter, Ann-Katrin
# Scraped details for Nguyen, Minh
# Scraped details for Görke, Bentje
# Scraped details for Steinhardt, Lisa
# Scraped details for Hunger, Anne Kristine
# Scraped details for Dirks, Jule Kira
# Scraped details for Wagner, Sarah
# Scraped details for Jabsen, Melina
# Scraped details for Dr. Nissen, Annik
# Scraped details for Kolmos, Evamaria
# Scraped details for Stuppmann, Marie Julie
# Scraped details for Gentzsch, Stefanie
# Scraped details for Hölkemann, Jessika
# Scraped details for Maier, Anne
# Scraped details for Hornauer, Anna-Lena
# Scraped details for Hübner, Sophia
# Scraped details for Schnell, Katrin
# Scraped details for Palisi, Anna
# Scraped details for Nickel, Alina
# Scraped details for Schäfer, Carmen
# Scraped details for Rasch, Nina
# Scraped details for Bitterschulte, Caro
# Scraped details for Lunkova, Eva
# Scraped details for Moritz, Jenni
# Scraped details for Scheppmann, Annica
# Scraped details for Kähler, Lisa
# Scraped details for Thiele, Sarah
# Scraped details for Adelfang, Raphaela
# Scraped details for Jasari, Laura
# Scraped details for Demchuk, Kateryna
# Scraped details for Haß, Miriam
# Scraped details for Albrecht, Monia
# Scraped details for Herzog, Katharina
# Scraped details for Wilhelms, Alexandra
# Scraped details for Mauer, Silja
# Scraped details for Von Lysander, Lara
# Scraped details for Boye, Britta
# Scraped details for Bohn, Victoria
# Scraped details for Bortel, Annica
# Completed 2600 of 3143 URLs.
# Estimated remaining time: 7.06 minutes.
# Scraped details for Jung, Figen
# Scraped details for Acolatsé, Tina
# Scraped details for Maderecker, Franziska
# Scraped details for Von Storch, Julie
# Scraped details for Bartelsen, Majbritt
# Scraped details for Weide, Anne
# Scraped details for Jenn, Friederike
# Scraped details for Vaelske, Vera
# Scraped details for Ryzmanek, Sarah
# Scraped details for Wunderlich, Huguette
# Scraped details for Friedrichs, Ina
# Scraped details for Remane, Britta
# Scraped details for Varankeviciute, Viktorija
# Scraped details for Pfullmann, Britta
# Scraped details for Lenschow, Alice
# Scraped details for Arps, Anja
# Scraped details for Fink, Lisa
# Scraped details for Blenke, Manuela
# Scraped details for Bause, Nicola
# Scraped details for Moussavi, Gitti
# Scraped details for Schwarzkopf, Almut
# Scraped details for Kubsch, Cindy
# Scraped details for Hölk, Andrea
# Scraped details for Pahlke, Chiara
# Scraped details for Masuhr, Yvonne
# Scraped details for Weiß, Caty
# Scraped details for Siehl, Friederike
# Scraped details for Le, To Uyen
# Scraped details for Soares Bastiao, Liane
# Scraped details for Jacob, Inga
# Scraped details for Krohn, Antonia
# Scraped details for Von Glahn, Tatjana
# Scraped details for formelke, Roxy
# Scraped details for Schlucke, Michéle
# Scraped details for Kluczny, Laura
# Scraped details for Jensen, Märit
# Scraped details for Wittholz, Valeska
# Scraped details for Addae, Joanna
# Scraped details for Vu, Hoa
# Scraped details for Napierala, Jill
# Scraped details for Lang, Henriette
# Scraped details for Drosdow, Vanessa
# Scraped details for Nanninga, Petra
# Scraped details for Hobler, Svenja
# Scraped details for Gerwoll, Marie
# Scraped details for Ferranti, Beatrice
# Scraped details for Johannes, Tessa
# Scraped details for Bick, Daniela
# Scraped details for Ohlrich, Ulrike
# Scraped details for Fresemann, Stephanie
# Scraped details for Vu, Dana
# Scraped details for Rolfes, Morsal
# Scraped details for Hobler, Lisa
# Scraped details for Röttger, Britta
# Scraped details for Chatenay, Claudia
# Scraped details for Dähn, Katharina
# Scraped details for Voigt, Andrea
# Scraped details for Dr. Schiffmann, Insa
# Scraped details for Mertens, Ronja
# Scraped details for Hackenberg, Henrika
# Scraped details for Gluth, Laura
# Scraped details for Grünig, Franziska
# Scraped details for Pischon, Yvette
# Scraped details for Langer, Sylvia
# Scraped details for Juhl, Tanja
# Scraped details for Leonhardt, Nina
# Scraped details for Crawford-Anton, Susanne
# Scraped details for Kremers, Annika
# Scraped details for Dugan, Tugba
# Scraped details for Radic, Nikolina
# Scraped details for Wong, Christine
# Scraped details for Mnich, Emilia
# Scraped details for Breuel, Katharina
# Scraped details for Schwindt-Urbanczyk, Tanja
# Scraped details for Westwood, Jennifer
# Scraped details for Frank, Monique
# Scraped details for Babicz, Janine
# Scraped details for Bock, Theresa
# Scraped details for Wichtrup, Joshua
# Scraped details for Nolde, Christian
# Scraped details for König, Torben
# Scraped details for Lüdeke, Jens
# Scraped details for Meier, Sebastian
# Scraped details for Bollwinkel, Jakob
# Scraped details for Neuwerk, Kevin
# Scraped details for Becke, Carlos
# Scraped details for Rowold, Johannes
# Scraped details for Bomm, Joss
# Scraped details for Krüger, René
# Scraped details for Johannesen, Eric
# Scraped details for Gasde, Philipp
# Scraped details for Woitack, Sören
# Scraped details for Pape, Stephan
# Scraped details for Jordt, Bosse
# Scraped details for Schulz, Finn
# Scraped details for Wenisch, Tim
# Scraped details for Wenisch, Tim
# Scraped details for Stahl, Phillip
# Scraped details for Kirfel, Konstantin
# Scraped details for Krupp, Stefan
# Completed 2700 of 3143 URLs.
# Estimated remaining time: 5.76 minutes.
# Scraped details for Geiken, Hilko
# Scraped details for Jordt, Mads
# Scraped details for Streit, Sebastian
# Scraped details for Stahl, Joerg
# Scraped details for Maier, Philipp
# Scraped details for Thode, Henrik
# Scraped details for Müller, Fabian
# Scraped details for Samaniego, Juan Martin
# Scraped details for Hermann, Richard
# Scraped details for Tananin, Stanislav
# Scraped details for Nsazukidi, Richie
# Scraped details for Ott, Patrick
# Scraped details for Friedrich, Christian
# Scraped details for Wissner, Marco
# Scraped details for Von Kopylow, Leon
# Scraped details for Homolka, Martin
# Scraped details for Calovius, Nico
# Scraped details for Schmidt, Jochen
# Scraped details for Kerstan, Philipp
# Scraped details for Maschmann, Christopher
# Scraped details for Meyer, Aike
# Scraped details for Bloch, Alexander
# Scraped details for Baust, Ricardo
# Scraped details for Greve, Jannik
# Scraped details for Sobottka, Michael
# Scraped details for Von Heimburg, Stefan
# Scraped details for Rogge, Timo
# Scraped details for Kasprzyck, Simon
# Scraped details for Santos, Jorge
# Scraped details for Holzinger, Bernard
# Scraped details for Kucharcik, Miroslav
# Scraped details for Saucke, Tobias
# Scraped details for Propp, Dmitrij
# Scraped details for Otto, Alexander
# Scraped details for Bohne, Patrick
# Scraped details for Kowalczyk, Florian
# Scraped details for Hamann, Daniel
# Scraped details for Schmidt, Marcel
# Scraped details for Ziemann, Timo
# Scraped details for Tacke, Tobias
# Scraped details for Schmidt, Jannik
# Scraped details for Giedt, Andreas
# Scraped details for Heinrich, Max
# Scraped details for Miegel, Marc
# Scraped details for Alkiewicz, Stefan
# Scraped details for Gierke, Bernhard
# Scraped details for Gouttenoire, Yann
# Scraped details for Krützelmann, Kevin
# Scraped details for Osterheider, Mattis
# Scraped details for Afarwuah, Kofi
# Scraped details for Müller, Torsten
# Scraped details for Schmidt, Marco
# Scraped details for Hrubesch, Kester
# Scraped details for Bresch, Philipp
# Scraped details for Kube, Dennis
# Scraped details for Scholz, Henning
# Scraped details for Iden, Leon
# Scraped details for Juergens, Tjard
# Scraped details for Orgaß, Timo
# Scraped details for Jahns, Steffen
# Scraped details for Schlinke, Torben
# Scraped details for Bastian, Fabian
# Scraped details for Stephan, Lennart
# Scraped details for Wachenfeld, Florian
# Scraped details for Marks, Marcel
# Scraped details for Schwarz, Ingo
# Scraped details for Krause, Alexander
# Scraped details for Anker-Ladefoged, Gustav
# Scraped details for Levitskiy, Stanislav
# Scraped details for Krüger, Lars
# Scraped details for Drusenthal, Sven
# Scraped details for Wagner, Erik
# Scraped details for Freese, Timo
# Scraped details for Schneider, Max

# %%
import csv

def flatten_participant_data(participant, all_splits):
    flat_data = {}

    # Flatten 'Participant' and 'Scoring' nested dictionaries
    for key in ['Participant', 'Scoring', 'Overall Time']:
        if key in participant:
            for sub_key, value in participant[key].items():
                flat_data[f"{key}_{sub_key}"] = value
            # Remove the original nested dictionary
            del participant[key]

    # Flatten 'Workout Result' list of dictionaries
    if 'Workout Result' in participant:
        for workout in participant['Workout Result']:
            split_name = workout['Split'].replace(' ', '_')  # Replace spaces with underscores
            flat_data[split_name] = workout['Time']
        # Remove the original 'Workout Result' list
        del participant['Workout Result']

    # Add remaining top-level key-values as is
    for key, value in participant.items():
        flat_data[key] = value

    return flat_data

def save_to_csv(participants, filename, all_splits):
    # Determine all fieldnames
    base_fields = ['Event ID','Participant_Name', 'Gender', 'Participant_Age Group', 'Participant_Number', 'Participant_Nat', 'Scoring_Race', 'Scoring_Division', 'Overall Time_Rank (M/W)', 'Overall Time_Rank (AG)', 'Overall Time_Overall Time']
    fieldnames = base_fields + all_splits

    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames, extrasaction='ignore')
        writer.writeheader()

        for participant in participants:
            flat_participant = flatten_participant_data(participant, all_splits)
            writer.writerow(flat_participant)

# Define all the specific splits
all_splits = [
    'Running_1','1000m_SkiErg', 'Running_2', '50m_Sled_Push', 'Running_3', '50m_Sled_Pull',
    'Running_4', '80m_Burpee_Broad_Jump', 'Running_5', '1000m_Row', 'Running_6',
    '200m_Farmers_Carry', 'Running_7', '100m_Sandbag_Lunges', 'Running_8',
    'Wall_Balls', 'Roxzone_Time', 'Run_Total', 'Best_Run_Lap'
]

# Example usage
filename = '/content/participants.csv'  # Adjust the path if needed
save_to_csv(all_details, filename, all_splits)

print(f"Data saved to {filename}")
# Out:
# Data saved to /content/participants.csv
